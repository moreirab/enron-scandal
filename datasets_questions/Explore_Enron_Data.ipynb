# %%
import pandas as pd

df = pd.DataFrame(pd.read_pickle('../final_project/final_project_dataset_unix2dos.pkl')).T
print(df.shape)
# Out:
# (146, 21)

# %%
print(sum(df.poi==1))
# Out:
# 18

# %%
pois=pd.read_csv('../final_project/poi_names.txt')
print(len(pois))
# Out:
# 35

# %%
print(df.loc['PRENTICE JAMES'].total_stock_value)
# Out:
# 1095040

# %%
print(df.loc['COLWELL WESLEY'].from_this_person_to_poi)
# Out:
# 11

# %%
print(df.loc['SKILLING JEFFREY K'].exercised_stock_options)
# Out:
# 19250000

# %%
display(df.loc['LAY KENNETH L'].total_payments)
# Out:
# 103559793

# %%
df.columns.tolist()
# Out:
# ['bonus',
#  'deferral_payments',
#  'deferred_income',
#  'director_fees',
#  'email_address',
#  'exercised_stock_options',
#  'expenses',
#  'from_messages',
#  'from_poi_to_this_person',
#  'from_this_person_to_poi',
#  'loan_advances',
#  'long_term_incentive',
#  'other',
#  'poi',
#  'restricted_stock',
#  'restricted_stock_deferred',
#  'salary',
#  'shared_receipt_with_poi',
#  'to_messages',
#  'total_payments',
#  'total_stock_value']

# %%
len(df[df.salary != 'NaN'])
# Out:
# 95

# %%
len(df[df.email_address != 'NaN'])
# Out:
# 111

# %%
len(df[df.total_payments == 'NaN'])/len(df.total_payments)*100
# Out:
# 14.383561643835616

# %%
len(df[(df.total_payments == 'NaN') & (df.poi == True)])/len(df.total_payments)*100
# Out:
# 0.0

# %%
df[(df.total_payments == 'NaN') & (df.poi == True)]
# Out:
# Empty DataFrame
# Columns: [bonus, deferral_payments, deferred_income, director_fees, email_address, exercised_stock_options, expenses, from_messages, from_poi_to_this_person, from_this_person_to_poi, loan_advances, long_term_incentive, other, poi, restricted_stock, restricted_stock_deferred, salary, shared_receipt_with_poi, to_messages, total_payments, total_stock_value]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[(df.total_payments == 'NaN')]
# Out:
#                        bonus deferral_payments deferred_income director_fees  \
# CORDES WILLIAM R         NaN               NaN             NaN           NaN
# LOWRY CHARLES P          NaN               NaN             NaN           NaN
# CHAN RONNIE              NaN               NaN          -98784         98784
# WHALEY DAVID A           NaN               NaN             NaN           NaN
# CLINE KENNETH W          NaN               NaN             NaN           NaN
# LEWIS RICHARD            NaN               NaN             NaN           NaN
# POWERS WILLIAM           NaN               NaN          -17500         17500
# PIRO JIM                 NaN               NaN             NaN           NaN
# WROBEL BRUCE             NaN               NaN             NaN           NaN
# MCDONALD REBECCA         NaN               NaN             NaN           NaN
# GATHMANN WILLIAM D       NaN               NaN             NaN           NaN
# ...
